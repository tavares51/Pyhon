# %%
try:
    a = int(input("Digite um número: "))
    b = int(input("Digite outro número: "))
    n = a / b
    print(n)
except Exception as e:
    print(e)
finally:
    pass
# Out:
# Digite um número: 3
# Digite outro número: 5
# 0.6

# %%
banana = -1
if banana < 1:
    raise Exception("banana menor que 1")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-18-0563c33b220f> in <module>
#       2
#       3 if banana < 1:
# ----> 4     raise Exception("banana menor que 1")
#
# Exception: banana menor que 1

# %%
banana = -1
try:
    if banana < 1:
        raise Exception("banana menor que 1")
except Exception as e:
    print(e)
# Out:
# banana menor que 1

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-449e7d699f5b> in <module>
# ----> 1 unicode
#
# NameError: name 'unicode' is not defined

# %%
type('㈲')
# Out:
# str
