# %%
example = ['Adriano', 4, 4.5, True]

print(type(example[3]))
# Out:
# <class 'bool'>

# %%
a = 3
print(id(a))

a = 5
print(id(a))
# Out:
# 11122656
# 11122720

# %%
exemplo_dicionario = { 
    'nome': 'Adriano', 
    'idade': 30, 
    'interesses': ['Motos', 'Informática'], 
    'contatos': {
        'celular': 'XXXXX', 
        'email': 'dsjkhdasjndlskjd'
    }
 }
